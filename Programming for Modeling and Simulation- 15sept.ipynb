# %%
#Exercise1
def main(): #defining the main
    v_membrane = float(-70) #initialize the membrane potential as a float
    v_membrane = v_membrane + 1 #incrementing the neuron membrane potential
    print(v_membrane) 
if __name__ == '__main__':
    main()
# Out:
# -69.0

# %%
#Exercise2
def main(): #firstly we decalre the var
    var = 1 #my debugger doesn't work for some reason but I know that this is an int variable
    var = var*0.7 #also I know by using the debugger the int variable transform in a float if I change the variable from 1 to 1.0
    print(var)
if __name__ == '__main__':
    main()
# Out:
# 0.7

# %%
#Exercise3
#neuron1.py code
import sys
membrane_potential = float(sys.argv[1])
if membrane_potential >= float(-65):
    print(5)
else:
    print(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 #Exercise3
#       2 #neuron1.py code
#       3 import sys
# ----> 4 membrane_potential = float(sys.argv[1])
#       5 if membrane_potential >= float(-65):
#       6     print(5)
#
# ValueError: could not convert string to float: '-f'

# %%
#neuron2.py code
import sys
spike = float(input())
membrane_potential = float(-65) + spike
print(membrane_potential)
# Out:
# 45
# -20.0

# %% [markdown]
# ![Screenshot%202023-09-15%20at%2016.50.26.png](attachment:Screenshot%202023-09-15%20at%2016.50.26.png)
